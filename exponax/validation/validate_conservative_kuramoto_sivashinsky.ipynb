# %% [markdown]
# # Validating the conservative Kuramoto Sivashinsky equation

# %% [markdown]
# Below is taken from [PDE-Refiner](https://arxiv.org/pdf/2308.05732) paper on
# page 21 which is the time-averaged spectrum of the conservative KS equation on $L=64$
# ![](attachment:b77b477f-d4dc-4f1f-a716-b613debfbd69.png)

# %%
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt

# %%
import exponax as ex

# %%
ks_conservative_stepper = ex.KuramotoSivashinskyConservative(1, 64, 250, 0.1)
# Out:
# 2024-03-01 12:04:59.792760: W external/xla/xla/service/platform_util.cc:198] unable to create StreamExecutor for CUDA:0: failed initializing StreamExecutor for CUDA device ordinal 0: INTERNAL: failed call to cuDevicePrimaryCtxRetain: CUDA_ERROR_OUT_OF_MEMORY: out of memory; total memory reported: 12606242816
# CUDA backend failed to initialize: INTERNAL: no supported devices found for platform CUDA (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
# Initial condition does not matter, it is only important that it has zero mean
u_0 = jax.random.normal(jax.random.PRNGKey(0), (1, ks_conservative_stepper.num_points))
u_0 = u_0 - jnp.mean(u_0)

# %%
trj = ex.rollout(ks_conservative_stepper, 5000, include_init=True)(u_0)

# %%
plt.figure(figsize=(10, 3))
plt.imshow(trj[:, 0, :].T, aspect="auto", cmap="RdBu_r", vmin=-2.5, vmax=2.5)

# %% [markdown]
# Let's choose the spectrum from time step 500 onwards; and slice out the singleton channel axis

# %%
chaotic_trj = trj[500:, 0, :]

# %% [markdown]
# Transform into Fourier space

# %%
chaotic_trj_hat = jnp.fft.rfft(chaotic_trj)

# %% [markdown]
# Average the mean over time

# %%
mean_amplitude = jnp.mean(jnp.abs(chaotic_trj_hat), axis=0)

# %%
plt.plot(mean_amplitude)
plt.yscale("log")
plt.ylim(1e-12, 1e3)
plt.grid()
